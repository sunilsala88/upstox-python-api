# %%
access_token='eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiIzVkNEQkYiLCJqdGkiOiI2ODQ3ZWUxNTI1NDU5YTJlZGZlMWQwYjEiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6ZmFsc2UsImlhdCI6MTc0OTU0NDQ2OSwiaXNzIjoidWRhcGktZ2F0ZXdheS1zZXJ2aWNlIiwiZXhwIjoxNzQ5NTkyODAwfQ.8-kHIru9ty2bhHXzMsLTgt-I9TGOOZuXahzf3s299jo'
access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiIzVkNEQkYiLCJqdGkiOiI2ODQ3ZWUxNTI1NDU5YTJlZGZlMWQwYjEiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6ZmFsc2UsImlhdCI6MTc0OTU0NDQ2OSwiaXNzIjoidWRhcGktZ2F0ZXdheS1zZXJ2aWNlIiwiZXhwIjoxNzQ5NTkyODAwfQ.8-kHIru9ty2bhHXzMsLTgt-I9TGOOZuXahzf3s299jo'

# %% [markdown]
# Historical Candle Data V3

# %%
import upstox_client
apiInstance = upstox_client.HistoryV3Api()
name='NSE_INDEX|Nifty Bank'
try:
    response = apiInstance.get_historical_candle_data1(name, "minutes", "15", "2025-01-02", "2025-01-01")
    print(response)
except Exception as e:
    print("Exception when calling HistoryV3Api->get_historical_candle_data1: %s\n" % e)
# Out:
# {'data': {'candles': [['2025-01-02T15:15:00+05:30',
#                        51602.35,
#                        51626.15,
#                        51585.2,
#                        51605.85,
#                        0,
#                        0],
#                       ['2025-01-02T15:00:00+05:30',
#                        51635.65,
#                        51637.8,
#                        51534.6,
#                        51604.0,
#                        0,
#                        0],
#                       ['2025-01-02T14:45:00+05:30',
#                        51601.7,
#                        51672.75,
#                        51591.6,
#                        51637.1,
#                        0,
#                        0],
#                       ['2025-01-02T14:30:00+05:30',
#                        51548.5,
#                        51655.75,
#                        51547.85,
#                        51601.1,
#                        0,
#                        0],
#                       ['2025-01-02T14:15:00+05:30',
#                        51518.6,
#                        51616.35,
#                        51518.6,
#                        51548.75,
#                        0,
#                        0],
#                       ['2025-01-02T14:00:00+05:30',
#                        51466.3,
#                        51546.1,
#                        51442.75,
#                        51520.6,
#                        0,
#                        0],
#                       ['2025-01-02T13:45:00+05:30',
#                        51568.85,
#                        51595.05,
#                        51458.15,
#                        51466.05,
#                        0,
#                        0],
#                       ['2025-01-02T13:30:00+05:30',
#                        51435.0,
#                        51586.2,
#                        51407.6,
#                        51573.35,
#                        0,
#                        0],
#                       ['2025-01-02T13:15:00+05:30',
#                        51342.6,
#                        51509.35,
#                        51339.45,
#                        51435.0,
#                        0,
#                        0],
#                       ['2025-01-02T13:00:00+05:30',
#                        51313.45,
#                        51370.55,
#                        51293.1,
#                        51347.15,
#                        0,
#                        0],
#                       ['2025-01-02T12:45:00+05:30',
#                        51321.0,
#                        51343.15,
#                        51264.4,
#                        51311.4,
#                        0,
#                        0],
#                       ['2025-01-02T12:30:00+05:30',
#                        51256.25,
#                        51355.45,
#                        51248.0,
#                        51319.2,
#                        0,
#                        0],
#                       ['2025-01-02T12:15:00+05:30',
#                        51129.5,
#                        51276.0,
#                        51081.6,
#                        51260.65,
#                        0,
#                        0],
#                       ['2025-01-02T12:00:00+05:30',
#                        51188.05,
#                        51238.1,
#                        51110.25,
#                        51126.6,
#                        0,
#                        0],
#                       ['2025-01-02T11:45:00+05:30',
#                        51265.25,
#                        51267.75,
#                        51143.65,
#                        51177.6,
#                        0,
#                        0],
#                       ['2025-01-02T11:30:00+05:30',
#                        51331.65,
#                        51350.15,
#                        51254.05,
#                        51262.75,
#                        0,
#                        0],
#                       ['2025-01-02T11:15:00+05:30',
#                        51276.95,
#                        51339.05,
#                        51236.5,
#                        51333.65,
#                        0,
#                        0],
#                       ['2025-01-02T11:00:00+05:30',
#                        51263.2,
#                        51317.35,
#                        51203.95,
#                        51275.85,
#                        0,
#                        0],
#                       ['2025-01-02T10:45:00+05:30',
#                        51196.25,
#                        51283.8,
#                        51154.7,
#                        51265.15,
#                        0,
#                        0],
#                       ['2025-01-02T10:30:00+05:30',
#                        51225.65,
#                        51232.45,
#                        51140.55,
#                        51196.25,
#                        0,
#                        0],
#                       ['2025-01-02T10:15:00+05:30',
#                        51110.15,
#                        51271.25,
#                        51103.0,
#                        51227.15,
#                        0,
#                        0],
#                       ['2025-01-02T10:00:00+05:30',
#                        51141.95,
#                        51230.05,
#                        51101.9,
#                        51109.8,
#                        0,
#                        0],
#                       ['2025-01-02T09:45:00+05:30',
#                        51153.95,
#                        51196.4,
#                        51045.3,
#                        51136.55,
#                        0,
#                        0],
#                       ['2025-01-02T09:30:00+05:30',
#                        51028.7,
#                        51202.5,
#                        50992.8,
#                        51155.2,
#                        0,
#                        0],
#                       ['2025-01-02T09:15:00+05:30',
#                        51084.95,
#                        51202.3,
#                        51030.85,
#                        51036.3,
#                        0,
#                        0],
#                       ['2025-01-01T15:15:00+05:30',
#                        51049.2,
#                        51122.95,
#                        51031.35,
#                        51096.05,
#                        0,
#                        0],
#                       ['2025-01-01T15:00:00+05:30',
#                        51067.9,
#                        51084.1,
#                        51001.85,
#                        51047.6,
#                        0,
#                        0],
#                       ['2025-01-01T14:45:00+05:30',
#                        51146.95,
#                        51149.9,
#                        51055.45,
#                        51067.9,
#                        0,
#                        0],
#                       ['2025-01-01T14:30:00+05:30',
#                        51198.1,
#                        51214.6,
#                        51148.5,
#                        51149.1,
#                        0,
#                        0],
#                       ['2025-01-01T14:15:00+05:30',
#                        51234.75,
#                        51250.85,
#                        51187.25,
#                        51198.9,
#                        0,
#                        0],
#                       ['2025-01-01T14:00:00+05:30',
#                        51232.9,
#                        51321.95,
#                        51207.5,
#                        51232.3,
#                        0,
#                        0],
#                       ['2025-01-01T13:45:00+05:30',
#                        51108.5,
#                        51229.25,
#                        51097.05,
#                        51228.7,
#                        0,
#                        0],
#                       ['2025-01-01T13:30:00+05:30',
#                        51073.75,
#                        51134.35,
#                        51055.15,
#                        51110.35,
#                        0,
#                        0],
#                       ['2025-01-01T13:15:00+05:30',
#                        51013.4,
#                        51084.15,
#                        51008.3,
#                        51078.25,
#                        0,
#                        0],
#                       ['2025-01-01T13:00:00+05:30',
#                        51037.65,
#                        51053.7,
#                        51001.6,
#                        51012.75,
#                        0,
#                        0],
#                       ['2025-01-01T12:45:00+05:30',
#                        51079.05,
#                        51131.95,
#                        51032.1,
#                        51034.2,
#                        0,
#                        0],
#                       ['2025-01-01T12:30:00+05:30',
#                        51097.95,
#                        51127.95,
#                        51046.6,
#                        51079.1,
#                        0,
#                        0],
#                       ['2025-01-01T12:15:00+05:30',
#                        51059.55,
#                        51153.75,
#                        51051.35,
#                        51098.8,
#                        0,
#                        0],
#                       ['2025-01-01T12:00:00+05:30',
#                        50994.7,
#                        51084.3,
#                        50986.5,
#                        51059.8,
#                        0,
#                        0],
#                       ['2025-01-01T11:45:00+05:30',
#                        51049.6,
#                        51079.0,
#                        50973.15,
#                        50996.2,
#                        0,
#                        0],
#                       ['2025-01-01T11:30:00+05:30',
#                        51059.45,
#                        51073.3,
#                        50971.1,
#                        51046.4,
#                        0,
#                        0],
#                       ['2025-01-01T11:15:00+05:30',
#                        51104.6,
#                        51169.05,
#                        51018.3,
#                        51056.2,
#                        0,
#                        0],
#                       ['2025-01-01T11:00:00+05:30',
#                        51105.45,
#                        51161.2,
#                        51060.65,
#                        51108.1,
#                        0,
#                        0],
#                       ['2025-01-01T10:45:00+05:30',
#                        50846.05,
#                        51154.3,
#                        50845.15,
#                        51110.25,
#                        0,
#                        0],
#                       ['2025-01-01T10:30:00+05:30',
#                        50879.15,
#                        50890.15,
#                        50798.3,
#                        50846.65,
#                        0,
#                        0],
#                       ['2025-01-01T10:15:00+05:30',
#                        50790.05,
#                        50884.0,
#                        50765.15,
#                        50884.0,
#                        0,
#                        0],
#                       ['2025-01-01T10:00:00+05:30',
#                        50608.75,
#                        50841.0,
#                        50579.25,
#                        50790.25,
#                        0,
#                        0],
#                       ['2025-01-01T09:45:00+05:30',
#                        50623.65,
#                        50629.65,
#                        50485.05,
#                        50611.35,
#                        0,
#                        0],
#                       ['2025-01-01T09:30:00+05:30',
#                        50739.9,
#                        50784.05,
#                        50572.35,
#                        50627.4,
#                        0,
#                        0],
#                       ['2025-01-01T09:15:00+05:30',
#                        50841.9,
#                        50970.7,
#                        50696.3,
#                        50741.85,
#                        0,
#                        0]]},
#  'status': 'success'}

# %%
import pandas as pd
import datetime as dt
def fetch_data(name,start,end,interval,interval_unit):
    response = apiInstance.get_historical_candle_data1(name, interval, interval_unit, end,start)
    data=response.data.candles
    data=pd.DataFrame(data,columns=['Timestamp','Open','High','Low','Close','Volume','Open Interest'])
    data['Timestamp']=pd.to_datetime(data['Timestamp'])
    data=data.set_index('Timestamp')
    data=data.sort_index()
    return data

name='NSE_INDEX|Nifty Bank'
days=300
end=dt.datetime.now().strftime('%Y-%m-%d')
start=(dt.datetime.now()-dt.timedelta(days)).strftime('%Y-%m-%d')
interval='days'
interval_unit='1'
data=fetch_data(name,start,end,interval,interval_unit)
data

# %% [markdown]
# Intraday Candle Data V3

# %%
import upstox_client
apiInstance = upstox_client.HistoryV3Api()
name='NSE_INDEX|Nifty Bank'
try:
    response = apiInstance.get_intra_day_candle_data(name, "minutes", "1")
    print(response)
except Exception as e:
    print("Exception when calling HistoryV3Api->get_intra_day_candle_data: %s\n" % e)

# %%
import pandas as pd
import datetime as dt
def fetch_data(name,start,end,interval,interval_unit):
    # response = apiInstance.get_historical_candle_data1(name, interval, interval_unit, end,start)
    response=apiInstance.get_intra_day_candle_data(name, interval,interval_unit)
    data=response.data.candles
    data=pd.DataFrame(data,columns=['Timestamp','Open','High','Low','Close','Volume','Open Interest'])
    data['Timestamp']=pd.to_datetime(data['Timestamp'])
    data=data.set_index('Timestamp')
    data=data.sort_index()
    return data

name='NSE_INDEX|Nifty Bank'
interval='minutes'
interval_unit='5'
data=fetch_data(name,start,end,interval,interval_unit)
data

# %% [markdown]
# full market quote

# %%
import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token
api_version = '2.0'

symbol ='NSE_INDEX|Nifty Bank'
symbol='NSE_EQ|INE002A01018'
api_instance = upstox_client.MarketQuoteApi(upstox_client.ApiClient(configuration))


try:
    api_response = api_instance.get_full_market_quote(symbol, api_version)
    print(api_response)
except ApiException as e:
    print("Exception when calling MarketQuoteApi->get_full_market_quote: %s\n" % e)
# Out:
# {'data': {'NSE_EQ:RELIANCE': {'average_price': 1442.59,
#                               'depth': {'buy': [{'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0},
#                                                 {'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0},
#                                                 {'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0},
#                                                 {'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0},
#                                                 {'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0}],
#                                         'sell': [{'orders': 35,
#                                                   'price': 1438.5,
#                                                   'quantity': 4122},
#                                                  {'orders': 0,
#                                                   'price': 0.0,
#                                                   'quantity': 0},
#                                                  {'orders': 0,
#                                                   'price': 0.0,
#                                                   'quantity': 0},
#                                                  {'orders': 0,
#                                                   'price': 0.0,
#                                                   'quantity': 0},
#                                                  {'orders': 0,
#                                                   'price': 0.0,
#                                                   'quantity': 0}]},
#                               'instrument_token': 'NSE_EQ|INE002A01018',
#                               'last_price': 1438.5,
#                               'last_trade_time': '1749551390864',
#                               'lower_circuit_limit': 1304.0,
#                               'net_change': -10.3,
#                               'ohlc': {'close': 1438.5,
#                                        'high': 1453.9,
#                                        'low': 1436.0,
#                                        'open': 1450.0},
#                               'oi': 0.0,
#                               'oi_day_high': 0.0,
#                               'oi_day_low': 0.0,
#                               'symbol': 'RELIANCE',
#                               'timestamp': '2025-06-10T17:18:20.09+05:30',
#                               'total_buy_quantity': 0.0,
#                               'total_sell_quantity': 4122.0,
#                               'upper_circuit_limit': 1593.6,
#                               'volume': 7913181}},
#  'status': 'success'}

# %% [markdown]
# market quote for multiple instrument

# %%
import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token
api_version = '2.0'

symbol=['NSE_INDEX|Nifty Bank','NSE_EQ|INE002A01018']
symbol=','.join(symbol)
# symbol = 'NSE_EQ|INE669E01016,NSE_EQ|INE848E01016'
api_instance = upstox_client.MarketQuoteApi(upstox_client.ApiClient(configuration))

try:
    api_response = api_instance.get_full_market_quote(symbol, api_version)
    print(api_response)
except ApiException as e:
    print("Exception when calling MarketQuoteApi->get_full_market_quote: %s\n" % e)
# Out:
# {'data': {'NSE_EQ:RELIANCE': {'average_price': 1442.59,
#                               'depth': {'buy': [{'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0},
#                                                 {'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0},
#                                                 {'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0},
#                                                 {'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0},
#                                                 {'orders': 0,
#                                                  'price': 0.0,
#                                                  'quantity': 0}],
#                                         'sell': [{'orders': 35,
#                                                   'price': 1438.5,
#                                                   'quantity': 4122},
#                                                  {'orders': 0,
#                                                   'price': 0.0,
#                                                   'quantity': 0},
#                                                  {'orders': 0,
#                                                   'price': 0.0,
#                                                   'quantity': 0},
#                                                  {'orders': 0,
#                                                   'price': 0.0,
#                                                   'quantity': 0},
#                                                  {'orders': 0,
#                                                   'price': 0.0,
#                                                   'quantity': 0}]},
#                               'instrument_token': 'NSE_EQ|INE002A01018',
#                               'last_price': 1438.5,
#                               'last_trade_time': '1749551390864',
#                               'lower_circuit_limit': 1304.0,
#                               'net_change': -10.3,
#                               'ohlc': {'close': 1438.5,
#                                        'high': 1453.9,
#                                        'low': 1436.0,
#                                        'open': 1450.0},
#                               'oi': 0.0,
#                               'oi_day_high': 0.0,
#                               'oi_day_low': 0.0,
#                               'symbol': 'RELIANCE',
#                               'timestamp': '2025-06-10T17:28:00.51+05:30',
#                               'total_buy_quantity': 0.0,
#                               'total_sell_quantity': 4122.0,
#                               'upper_circuit_limit': 1593.6,
#                               'volume': 7913181},
#           'NSE_INDEX:Nifty Bank': {'average_price': None,
#                                    'depth': {'buy': [], 'sell': []},
#                                    'instrument_token': 'NSE_INDEX|Nifty Bank',
#                                    'last_price': 56629.1,
#                                    'last_trade_time': '1749551400000',
#                                    'lower_circuit_limit': None,
#                                    'net_change': -210.5,
#                                    'ohlc': {'close': 56629.1,
#                                             'high': 57015.4,
#                                             'low': 56564.15,
#                                             'open': 56993.9},
#                                    'oi': None,
#                                    'oi_day_high': None,
#                                    'oi_day_low': None,
#                                    'symbol': 'NA',
#                                    'timestamp': '2025-06-10T17:28:00.51+05:30',
#                                    'total_buy_quantity': None,
#                                    'total_sell_quantity': None,
#                                    'upper_circuit_limit': None,
#                                    'volume': None}},
#  'status': 'success'}

# %% [markdown]
# OHLC Quotes V3

# %%
name='MCX_FO|445826'


import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token

apiInstance = upstox_client.MarketQuoteV3Api(upstox_client.ApiClient(configuration))
try:
    # For a single instrument
    response = apiInstance.get_market_quote_ohlc("1d", instrument_key=name)
    print(response)
except ApiException as e:
    print("Exception when calling MarketQuoteV3Api->get_market_quote_ohlc: %s\n" % e)
# Out:
# {'data': {'MCX_FO:CRUDEOILM25JUNFUT': {'instrument_token': 'MCX_FO|445826',
#                                        'last_price': 5618.0,
#                                        'live_ohlc': {'close': 5618.0,
#                                                      'high': 5626.0,
#                                                      'low': 5580.0,
#                                                      'open': 5597.0,
#                                                      'ts': 1749493800000,
#                                                      'volume': 8850},
#                                        'prev_ohlc': None}},
#  'status': 'success'}

# %% [markdown]
# LTP Quotes V3

# %%
import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token

apiInstance = upstox_client.MarketQuoteV3Api(upstox_client.ApiClient(configuration))
try:
    # For a single instrument
    response = apiInstance.get_ltp(instrument_key=name)
    print(response)
except ApiException as e:
    print("Exception when calling MarketQuoteV3Api->get_ltp: %s\n" % e)
# Out:
# {'data': {'MCX_FO:CRUDEOILM25JUNFUT': {'cp': 5564.0,
#                                        'instrument_token': 'MCX_FO|445826',
#                                        'last_price': 5618.0,
#                                        'ltq': 30,
#                                        'volume': 8850}},
#  'status': 'success'}

# %% [markdown]
# option chain

# %%
import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token

api_instance = upstox_client.OptionsApi(upstox_client.ApiClient(configuration))

try:
    api_response = api_instance.get_option_contracts("NSE_INDEX|Nifty 50")
    print(api_response)
except ApiException as e:
    print("Exception when calling OrderApi->options apis: %s\n" % e.body)
# Out:
# {'data': [{'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50847',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50847',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 22800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 22800 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50848',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50848',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 22800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 22800 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50850',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50850',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 22850.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 22850 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50852',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50852',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 22900.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 22900 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50856',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50856',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 22950.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 22950 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50858',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50858',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23000 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50859',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50859',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23050.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23050 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50860',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50860',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23050.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23050 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50863',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50863',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23100.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23100 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50874',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50874',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23100.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23100 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50876',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50876',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23150.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23150 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50881',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50881',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23250.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23250 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50882',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50882',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23250.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23250 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50883',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50883',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23300.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23300 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50884',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50884',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23300.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23300 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50885',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50885',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23350.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23350 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50886',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50886',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23350.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23350 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50895',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50895',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23400.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23400 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50896',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50896',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23400.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23400 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50897',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50897',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23450.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23450 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50898',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50898',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23450.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23450 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50899',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50899',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23500 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50917',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50917',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23550.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23550 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50944',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50944',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 23800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 23800 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51000',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51000',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 24750.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 24750 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51016',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51016',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 25100.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 25100 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51049',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51049',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 25850.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 25850 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51076',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51076',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26450.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26450 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51077',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51077',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26500 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51078',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51078',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26500 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51079',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51079',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26550.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26550 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51082',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51082',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26550.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26550 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51083',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51083',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26600.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26600 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51085',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51085',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26650.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26650 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51086',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51086',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26650.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26650 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51087',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51087',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26700.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26700 CE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51088',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51088',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26700.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26700 PE 19 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51089',
#            'expiry': datetime.datetime(2025, 6, 19, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51089',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26750.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26750 CE 19 JUN 25',
# ...
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 27000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 27000 CE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53633',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53633',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 28000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 28000 CE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53635',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53635',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 28000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 28000 PE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '35346',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|35346',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 30000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 30000 CE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53615',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53615',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21000 PE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53630',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53630',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26000 PE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53632',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53632',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 27000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 27000 PE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53595',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53595',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 15000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 15000 PE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53602',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53602',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 17000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 17000 PE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53603',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53603',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 18000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 18000 CE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53604',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53604',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 18000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 18000 PE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53606',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53606',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 19000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 19000 PE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '53613',
#            'expiry': datetime.datetime(2027, 12, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|53613',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21000 CE 30 DEC 27',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False}],
#  'status': 'success'}

# %%
param = {
    'expiry_date': "2025-06-26"
}
try:
    api_response = api_instance.get_option_contracts("NSE_INDEX|Nifty Bank", **param)
    print(api_response)
except ApiException as e:
    print("Exception when calling OrderApi->options apis: %s\n" % e.body)
# Out:
# {'data': [{'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '50508',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|50508',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 51000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 51000 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54787',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54787',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 52500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 52500 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54789',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54789',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 54000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 54000 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54791',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54791',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 55500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 55500 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54793',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54793',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 57000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 57000 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54796',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54796',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 58500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 58500 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54797',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54797',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 60000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 60000 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54798',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54798',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 60000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 60000 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54799',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54799',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 61500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 61500 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54800',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54800',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 61500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 61500 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54802',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54802',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 63000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 63000 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '47345',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|47345',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 40500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 40500 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '47647',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|47647',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 42000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 42000 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '47648',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|47648',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 42000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 42000 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48306',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48306',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 46500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 46500 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54794',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54794',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 57000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 57000 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '47354',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|47354',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 40500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 40500 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48302',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48302',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 43500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 43500 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48303',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48303',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 43500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 43500 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48304',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48304',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 45000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 45000 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48305',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48305',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 45000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 45000 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48307',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48307',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 46500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 46500 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48308',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48308',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 48000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 48000 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48313',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48313',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 48000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 48000 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48314',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48314',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 49500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 49500 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '48316',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|48316',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 49500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 49500 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54801',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54801',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 63000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 63000 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54803',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54803',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 64500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 64500 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '54804',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|54804',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 64500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 64500 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57601',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57601',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 44900.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 44900 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57624',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57624',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 46200.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 46200 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57626',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57626',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 46300.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 46300 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57629',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57629',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 46400.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 46400 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57631',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57631',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 46600.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 46600 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57633',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57633',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 46700.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 46700 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57635',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57635',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 46800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 46800 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57637',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57637',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 46900.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 46900 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57639',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57639',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
# ...
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 56000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 56000 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57851',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57851',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 56100.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 56100 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57853',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57853',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 56200.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 56200 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57855',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57855',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 56300.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 56300 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57906',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57906',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 56600.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 56600 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57909',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57909',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 56800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 56800 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57937',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57937',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 58200.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 58200 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57944',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57944',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 58600.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 58600 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57976',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57976',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 58800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 58800 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57978',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57978',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 58900.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 58900 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '57980',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|57980',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 59000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 59000 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '58078',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|58078',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 59700.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 59700 CE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '58135',
#            'expiry': datetime.datetime(2025, 6, 26, 0, 0),
#            'freeze_quantity': 600.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|58135',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 30,
#            'minimum_lot': 30,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'BANKNIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 60800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'BANKNIFTY 60800 PE 26 JUN 25',
#            'underlying_key': 'NSE_INDEX|Nifty Bank',
#            'underlying_symbol': 'BANKNIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': False}],
#  'status': 'success'}

# %%
import pandas as pd
d = api_response.data
d
instrument_dicts = [item.to_dict() for item in d]
data=pd.DataFrame(instrument_dicts)
data.to_csv("instruments.csv", index=False)
data
# Out:
#           name segment exchange  isin     expiry country latency description  \
# 0    BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
# 1    BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
# 2    BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
# 3    BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
# 4    BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
# ..         ...     ...      ...   ...        ...     ...     ...         ...
# 361  BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
# 362  BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
# 363  BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
# 364  BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
# 365  BANKNIFTY  NSE_FO      NSE  None 2025-06-26    None    None        None
#
#     currency  weekly  ... start_time end_time week_days general_denominator  \
# 0       None   False  ...       None     None      None                None
# 1       None   False  ...       None     None      None                None
# 2       None   False  ...       None     None      None                None
# 3       None   False  ...       None     None      None                None
# 4       None   False  ...       None     None      None                None
# ..       ...     ...  ...        ...      ...       ...                 ...
# 361     None   False  ...       None     None      None                None
# 362     None   False  ...       None     None      None                None
# 363     None   False  ...       None     None      None                None
# 364     None   False  ...       None     None      None                None
# 365     None   False  ...       None     None      None                None
#
#      general_numerator  price_numerator price_denominator  mtf_enabled  \
# 0                 None             None              None         None
# 1                 None             None              None         None
# 2                 None             None              None         None
# 3                 None             None              None         None
# 4                 None             None              None         None
# ..                 ...              ...               ...          ...
# 361               None             None              None         None
# 362               None             None              None         None
# 363               None             None              None         None
# 364               None             None              None         None
# 365               None             None              None         None
#
#     mtf_bracket security_type
# 0          None          None
# 1          None          None
# 2          None          None
# 3          None          None
# 4          None          None
# ..          ...           ...
# 361        None          None
# 362        None          None
# 363        None          None
# 364        None          None
# 365        None          None
#
# [366 rows x 36 columns]

# %% [markdown]
# option greek

# %%
import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token

apiInstance = upstox_client.MarketQuoteV3Api(upstox_client.ApiClient(configuration))
try:
    # For a single instrument
    response = apiInstance.get_market_quote_option_greek(instrument_key="NSE_FO|57912")
    print(response)
except ApiException as e:
    print("Exception when calling MarketQuoteV3Api->get_market_quote_option_greek: %s\n" % e)
# Out:
# {'data': {'NSE_FO:BANKNIFTY25JUN56900PE': {'cp': 713.0,
#                                            'delta': -0.5325,
#                                            'gamma': 0.0002,
#                                            'instrument_token': 'NSE_FO|57912',
#                                            'iv': 0.14362335205078125,
#                                            'last_price': 766.35,
#                                            'ltq': 90,
#                                            'oi': 126870.0,
#                                            'theta': -21.1985,
#                                            'vega': 47.2315,
#                                            'volume': 1307070}},
#  'status': 'success'}

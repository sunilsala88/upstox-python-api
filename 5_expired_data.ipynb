# %%
access_token="eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiIzVkNEQkYiLCJqdGkiOiI2ODQ3YzBjYjg1YTA2MzRhMWU4YTI5N2EiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6dHJ1ZSwiaWF0IjoxNzQ5NTMyODc1LCJpc3MiOiJ1ZGFwaS1nYXRld2F5LXNlcnZpY2UiLCJleHAiOjE3NDk1OTI4MDB9.VOixYrJn7vRl8BRYGrYJfwawFuRxVuztLt6Ngv9vh3M"

# %% [markdown]
# Get Expiries

# %%
import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token
apiInstance = upstox_client.ExpiredInstrumentApi(upstox_client.ApiClient(configuration))
try:
    response = apiInstance.get_expiries("NSE_INDEX|Nifty 50")
    print(response)
except ApiException as e:
    print("Exception when calling expired instrument v3 api: %s\n" % e)
# Out:
# {'data': ['2024-10-03',
#           '2024-10-10',
#           '2024-10-17',
#           '2024-10-24',
#           '2024-10-31',
#           '2024-11-07',
#           '2024-11-14',
#           '2024-11-21',
#           '2024-11-28',
#           '2024-12-05',
#           '2024-12-12',
#           '2024-12-19',
#           '2024-12-26',
#           '2025-01-02',
#           '2025-01-09',
#           '2025-01-16',
#           '2025-01-23',
#           '2025-01-30',
#           '2025-02-06',
#           '2025-02-13',
#           '2025-02-20',
#           '2025-02-27',
#           '2025-03-06',
#           '2025-03-13',
#           '2025-03-20',
#           '2025-03-27',
#           '2025-04-03',
#           '2025-04-09',
#           '2025-04-17',
#           '2025-04-24',
#           '2025-04-30',
#           '2025-05-08',
#           '2025-05-15',
#           '2025-05-22',
#           '2025-05-29',
#           '2025-06-05'],
#  'status': 'success'}

# %% [markdown]
# get expired contracts

# %%
import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token
apiInstance = upstox_client.ExpiredInstrumentApi(upstox_client.ApiClient(configuration))
try:
    response = apiInstance.get_expired_option_contracts("NSE_INDEX|Nifty 50", "2025-04-30")
    print(response)
except ApiException as e:
    print("Exception when calling expired instrument api: %s\n" % e)
# Out:
# {'data': [{'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51761',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51761|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20400.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20400 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51760',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51760|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20400.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20400 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51763',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51763|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20450.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20450 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51762',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51762|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20450.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20450 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51765',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51765|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20500 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51764',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51764|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20500.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20500 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51767',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51767|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20550.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20550 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51766',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51766|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20550.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20550 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51771',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51771|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20600.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20600 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51770',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51770|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20600.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20600 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51775',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51775|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20650.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20650 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51773',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51773|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20650.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20650 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51777',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51777|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20700.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20700 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51776',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51776|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20700.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20700 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51779',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51779|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20750.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20750 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51778',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51778|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20750.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20750 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51785',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51785|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20800 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51780',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51780|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20800 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51787',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51787|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20850.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20850 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51786',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51786|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20850.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20850 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51789',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51789|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20900.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20900 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51788',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51788|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20900.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20900 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51795',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51795|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20950.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20950 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51790',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51790|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 20950.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 20950 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51797',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51797|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21000 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51796',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51796|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21000 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51799',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51799|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21050.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21050 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51798',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51798|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21050.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21050 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51803',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51803|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21100.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21100 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51802',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51802|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21100.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21100 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51809',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51809|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21150.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21150 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51805',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51805|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21150.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21150 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51811',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51811|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21200.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21200 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51810',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51810|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21200.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21200 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51819',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51819|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21250.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21250 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51812',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51812|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21250.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21250 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51821',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51821|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 21300.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 21300 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '51820',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|51820|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
# ...
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 25800.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 25800 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52117',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52117|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 25850.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 25850 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52116',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52116|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 25850.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 25850 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52121',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52121|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 25900.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 25900 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52118',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52118|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 25900.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 25900 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52123',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52123|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 25950.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 25950 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52122',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52122|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 25950.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 25950 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52126',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52126|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26000 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52124',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52124|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26000.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26000 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52128',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52128|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26050.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26050 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52127',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52127|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26050.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26050 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52130',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52130|30-04-2025',
#            'instrument_type': 'PE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26100.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26100 PE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True},
#           {'country': None,
#            'currency': None,
#            'description': None,
#            'end_time': None,
#            'exchange': 'NSE',
#            'exchange_token': '52129',
#            'expiry': datetime.datetime(2025, 4, 30, 0, 0),
#            'freeze_quantity': 1800.0,
#            'general_denominator': None,
#            'general_numerator': None,
#            'instrument_key': 'NSE_FO|52129|30-04-2025',
#            'instrument_type': 'CE',
#            'isin': None,
#            'last_trading_date': None,
#            'latency': None,
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'mtf_bracket': None,
#            'mtf_enabled': None,
#            'name': 'NIFTY',
#            'price_denominator': None,
#            'price_numerator': None,
#            'price_quote_unit': None,
#            'qty_multiplier': None,
#            'security_type': None,
#            'segment': 'NSE_FO',
#            'short_name': None,
#            'start_time': None,
#            'strike_price': 26100.0,
#            'tick_size': 5.0,
#            'trading_symbol': 'NIFTY 26100 CE 30 APR 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX',
#            'week_days': None,
#            'weekly': True}],
#  'status': 'success'}

# %%
import pandas as pd
d = response.data
instrument_dicts = [item.to_dict() for item in d]
data=pd.DataFrame(instrument_dicts)
# data.to_csv("expired_instruments.csv", index=False)
data
# Out:
#       name segment exchange  isin     expiry country latency description  \
# 0    NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
# 1    NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
# 2    NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
# 3    NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
# 4    NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
# ..     ...     ...      ...   ...        ...     ...     ...         ...
# 225  NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
# 226  NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
# 227  NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
# 228  NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
# 229  NIFTY  NSE_FO      NSE  None 2025-04-30    None    None        None
#
#     currency  weekly  ... start_time end_time week_days general_denominator  \
# 0       None    True  ...       None     None      None                None
# 1       None    True  ...       None     None      None                None
# 2       None    True  ...       None     None      None                None
# 3       None    True  ...       None     None      None                None
# 4       None    True  ...       None     None      None                None
# ..       ...     ...  ...        ...      ...       ...                 ...
# 225     None    True  ...       None     None      None                None
# 226     None    True  ...       None     None      None                None
# 227     None    True  ...       None     None      None                None
# 228     None    True  ...       None     None      None                None
# 229     None    True  ...       None     None      None                None
#
#      general_numerator  price_numerator price_denominator  mtf_enabled  \
# 0                 None             None              None         None
# 1                 None             None              None         None
# 2                 None             None              None         None
# 3                 None             None              None         None
# 4                 None             None              None         None
# ..                 ...              ...               ...          ...
# 225               None             None              None         None
# 226               None             None              None         None
# 227               None             None              None         None
# 228               None             None              None         None
# 229               None             None              None         None
#
#     mtf_bracket security_type
# 0          None          None
# 1          None          None
# 2          None          None
# 3          None          None
# 4          None          None
# ..          ...           ...
# 225        None          None
# 226        None          None
# 227        None          None
# 228        None          None
# 229        None          None
#
# [230 rows x 36 columns]

# %% [markdown]
# expired future contract

# %%
import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token
apiInstance = upstox_client.ExpiredInstrumentApi(upstox_client.ApiClient(configuration))
try:
    response = apiInstance.get_expired_future_contracts("NSE_INDEX|Nifty 50", "2025-05-29")
    print(response)
except ApiException as e:
    print("Exception when calling expired instrument api: %s\n" % e)
# Out:
# {'data': [{'exchange': 'NSE',
#            'exchange_token': '57133',
#            'expiry': '2025-05-29',
#            'freeze_quantity': 1800.0,
#            'instrument_key': 'NSE_FO|57133|29-05-2025',
#            'instrument_type': 'FUT',
#            'lot_size': 75,
#            'minimum_lot': 75,
#            'name': 'NIFTY',
#            'segment': 'NSE_FO',
#            'tick_size': 10.0,
#            'trading_symbol': 'NIFTY FUT 29 MAY 25',
#            'underlying_key': 'NSE_INDEX|Nifty 50',
#            'underlying_symbol': 'NIFTY',
#            'underlying_type': 'INDEX'}],
#  'status': 'success'}

# %% [markdown]
# expired historical data

# %%
import upstox_client
from upstox_client.rest import ApiException

configuration = upstox_client.Configuration()
configuration.access_token = access_token
apiInstance = upstox_client.ExpiredInstrumentApi(upstox_client.ApiClient(configuration))
try:
    response = apiInstance.get_expired_historical_candle_data("NSE_FO|54452|24-04-2025", "1minute", "2025-04-24", "2025-04-11")
    print(response)
except ApiException as e:
    print("Exception when calling expired instrument api: %s\n" % e)
# Out:
# {'data': {'candles': [['2025-04-24T15:29:00+05:30',
#                        24249.7,
#                        24250.0,
#                        24246.0,
#                        24249.0,
#                        10875,
#                        4850775],
#                       ['2025-04-24T15:28:00+05:30',
#                        24249.9,
#                        24250.0,
#                        24247.0,
#                        24249.3,
#                        9600,
#                        4850775],
#                       ['2025-04-24T15:27:00+05:30',
#                        24248.0,
#                        24250.0,
#                        24248.0,
#                        24248.2,
#                        12525,
#                        4880250],
#                       ['2025-04-24T15:26:00+05:30',
#                        24248.8,
#                        24248.8,
#                        24246.0,
#                        24248.0,
#                        9375,
#                        4880250],
#                       ['2025-04-24T15:25:00+05:30',
#                        24247.2,
#                        24249.0,
#                        24246.8,
#                        24247.0,
#                        13275,
#                        4880250],
#                       ['2025-04-24T15:24:00+05:30',
#                        24247.9,
#                        24248.0,
#                        24247.0,
#                        24247.2,
#                        13275,
#                        4909725],
#                       ['2025-04-24T15:23:00+05:30',
#                        24247.0,
#                        24248.0,
#                        24246.3,
#                        24247.9,
#                        17100,
#                        4909725],
#                       ['2025-04-24T15:22:00+05:30',
#                        24247.6,
#                        24248.0,
#                        24246.3,
#                        24247.0,
#                        11925,
#                        4909725],
#                       ['2025-04-24T15:21:00+05:30',
#                        24246.7,
#                        24248.0,
#                        24246.2,
#                        24247.6,
#                        14025,
#                        4925700],
#                       ['2025-04-24T15:20:00+05:30',
#                        24248.1,
#                        24248.1,
#                        24246.0,
#                        24246.6,
#                        18825,
#                        4925700],
#                       ['2025-04-24T15:19:00+05:30',
#                        24246.2,
#                        24250.0,
#                        24246.2,
#                        24248.0,
#                        12375,
#                        4925700],
#                       ['2025-04-24T15:18:00+05:30',
#                        24249.6,
#                        24250.0,
#                        24246.0,
#                        24246.2,
#                        11475,
#                        4932600],
#                       ['2025-04-24T15:17:00+05:30',
#                        24246.0,
#                        24249.9,
#                        24245.2,
#                        24249.9,
#                        16200,
#                        4932600],
#                       ['2025-04-24T15:16:00+05:30',
#                        24245.9,
#                        24247.0,
#                        24244.0,
#                        24245.9,
#                        22050,
#                        4932600],
#                       ['2025-04-24T15:15:00+05:30',
#                        24246.1,
#                        24248.0,
#                        24245.5,
#                        24246.5,
#                        16650,
#                        4995300],
#                       ['2025-04-24T15:14:00+05:30',
#                        24245.6,
#                        24247.9,
#                        24245.6,
#                        24246.6,
#                        11250,
#                        4995300],
#                       ['2025-04-24T15:13:00+05:30',
#                        24245.0,
#                        24247.9,
#                        24245.0,
#                        24247.9,
#                        12225,
#                        4995300],
#                       ['2025-04-24T15:12:00+05:30',
#                        24245.8,
#                        24248.0,
#                        24244.8,
#                        24245.0,
#                        13650,
#                        5008425],
#                       ['2025-04-24T15:11:00+05:30',
#                        24244.0,
#                        24248.8,
#                        24244.0,
#                        24245.8,
#                        33300,
#                        5008425],
#                       ['2025-04-24T15:10:00+05:30',
#                        24245.0,
#                        24245.0,
#                        24242.1,
#                        24244.3,
#                        12450,
#                        5008425],
#                       ['2025-04-24T15:09:00+05:30',
#                        24241.4,
#                        24245.0,
#                        24241.2,
#                        24243.0,
#                        7800,
#                        5008800],
#                       ['2025-04-24T15:08:00+05:30',
#                        24244.0,
#                        24245.9,
#                        24241.2,
#                        24241.2,
#                        10800,
#                        5008800],
#                       ['2025-04-24T15:07:00+05:30',
#                        24241.3,
#                        24245.9,
#                        24240.8,
#                        24245.9,
#                        20400,
#                        5008800],
#                       ['2025-04-24T15:06:00+05:30',
#                        24246.0,
#                        24248.1,
#                        24239.4,
#                        24242.9,
#                        13875,
#                        5037825],
#                       ['2025-04-24T15:05:00+05:30',
#                        24245.6,
#                        24247.9,
#                        24242.2,
#                        24246.0,
#                        16650,
#                        5037825],
#                       ['2025-04-24T15:04:00+05:30',
#                        24245.0,
#                        24245.6,
#                        24242.0,
#                        24245.6,
#                        7575,
#                        5037825],
#                       ['2025-04-24T15:03:00+05:30',
#                        24244.0,
#                        24245.9,
#                        24240.0,
#                        24245.9,
#                        9525,
#                        5051475],
#                       ['2025-04-24T15:02:00+05:30',
#                        24240.0,
#                        24245.9,
#                        24238.8,
#                        24245.3,
#                        14250,
#                        5051475],
#                       ['2025-04-24T15:01:00+05:30',
#                        24246.3,
#                        24248.1,
#                        24239.9,
#                        24240.0,
#                        9750,
#                        5051475],
#                       ['2025-04-24T15:00:00+05:30',
#                        24238.0,
#                        24249.3,
#                        24235.0,
#                        24248.0,
#                        20625,
#                        5067000],
#                       ['2025-04-24T14:59:00+05:30',
#                        24241.4,
#                        24242.0,
#                        24236.0,
#                        24240.5,
#                        7275,
#                        5067000],
#                       ['2025-04-24T14:58:00+05:30',
#                        24239.0,
#                        24244.5,
#                        24236.5,
#                        24244.0,
#                        10575,
#                        5067000],
#                       ['2025-04-24T14:57:00+05:30',
#                        24236.0,
#                        24240.0,
#                        24234.9,
#                        24239.0,
#                        7500,
#                        5071425],
#                       ['2025-04-24T14:56:00+05:30',
#                        24239.9,
#                        24241.7,
#                        24234.0,
#                        24235.7,
#                        13875,
#                        5071425],
#                       ['2025-04-24T14:55:00+05:30',
#                        24238.2,
#                        24243.0,
#                        24235.0,
#                        24239.8,
#                        6750,
#                        5071425],
#                       ['2025-04-24T14:54:00+05:30',
#                        24240.0,
#                        24241.9,
#                        24225.0,
#                        24235.0,
#                        29400,
#                        5076525],
#                       ['2025-04-24T14:53:00+05:30',
#                        24236.9,
#                        24243.8,
#                        24236.9,
#                        24236.9,
#                        14625,
#                        5076525],
#                       ['2025-04-24T14:52:00+05:30',
#                        24247.3,
#                        24247.3,
#                        24232.5,
#                        24235.6,
#                        24450,
#                        5076525],
#                       ['2025-04-24T14:51:00+05:30',
#                        24245.0,
#                        24248.0,
#                        24244.0,
#                        24245.0,
#                        6450,
#                        5085000],
#                       ['2025-04-24T14:50:00+05:30',
#                        24251.5,
#                        24251.5,
#                        24245.1,
#                        24248.6,
#                        8775,
#                        5085000],
#                       ['2025-04-24T14:49:00+05:30',
#                        24250.0,
#                        24252.4,
#                        24248.0,
#                        24251.5,
#                        13350,
#                        5085000],
#                       ['2025-04-24T14:48:00+05:30',
#                        24250.5,
#                        24252.3,
#                        24250.0,
#                        24250.0,
#                        7800,
#                        5089950],
#                       ['2025-04-24T14:47:00+05:30',
#                        24251.0,
#                        24251.8,
#                        24249.0,
#                        24250.5,
#                        8550,
#                        5089950],
#                       ['2025-04-24T14:46:00+05:30',
#                        24248.1,
#                        24251.0,
#                        24248.1,
#                        24251.0,
#                        4950,
#                        5089950],
#                       ['2025-04-24T14:45:00+05:30',
#                        24252.3,
#                        24252.3,
#                        24248.0,
#                        24249.0,
#                        8400,
#                        5100825],
#                       ['2025-04-24T14:44:00+05:30',
#                        24250.0,
#                        24252.3,
#                        24249.0,
#                        24252.3,
#                        7350,
#                        5100825],
#                       ['2025-04-24T14:43:00+05:30',
#                        24249.1,
#                        24250.0,
#                        24247.0,
#                        24250.0,
#                        4275,
#                        5100825],
#                       ['2025-04-24T14:42:00+05:30',
#                        24248.7,
#                        24250.0,
#                        24248.7,
#                        24249.1,
#                        6600,
#                        5104050],
#                       ['2025-04-24T14:41:00+05:30',
#                        24249.8,
#                        24250.0,
#                        24245.1,
#                        24250.0,
#                        12825,
#                        5104050],
#                       ['2025-04-24T14:40:00+05:30',
#                        24248.9,
#                        24250.0,
#                        24245.0,
#                        24250.0,
#                        6675,
#                        5104050],
#                       ['2025-04-24T14:39:00+05:30',
#                        24247.0,
#                        24249.6,
#                        24247.0,
#                        24249.2,
#                        7950,
#                        5105025],
#                       ['2025-04-24T14:38:00+05:30',
#                        24249.2,
#                        24249.6,
#                        24244.1,
#                        24248.9,
#                        6225,
#                        5105025],
#                       ['2025-04-24T14:37:00+05:30',
#                        24248.1,
#                        24249.7,
#                        24242.9,
#                        24249.5,
#                        10500,
#                        5105025],
#                       ['2025-04-24T14:36:00+05:30',
#                        24249.0,
#                        24249.8,
#                        24246.0,
#                        24249.8,
#                        7200,
#                        5095350],
#                       ['2025-04-24T14:35:00+05:30',
#                        24247.1,
#                        24250.0,
#                        24247.1,
#                        24250.0,
#                        4500,
#                        5095350],
#                       ['2025-04-24T14:34:00+05:30',
#                        24248.8,
#                        24251.3,
#                        24246.3,
#                        24248.0,
#                        13725,
#                        5095350],
#                       ['2025-04-24T14:33:00+05:30',
#                        24252.5,
#                        24252.5,
#                        24248.8,
#                        24248.8,
#                        13275,
#                        5089875],
#                       ['2025-04-24T14:32:00+05:30',
#                        24251.0,
#                        24253.0,
#                        24250.6,
#                        24251.0,
#                        8700,
#                        5089875],
#                       ['2025-04-24T14:31:00+05:30',
#                        24254.8,
#                        24255.3,
#                        24250.6,
#                        24251.0,
#                        5025,
#                        5089875],
#                       ['2025-04-24T14:30:00+05:30',
#                        24253.0,
#                        24257.0,
#                        24250.7,
#                        24250.7,
#                        8175,
#                        5088300],
#                       ['2025-04-24T14:29:00+05:30',
#                        24251.2,
#                        24257.7,
#                        24251.0,
#                        24256.1,
#                        7875,
#                        5088300],
#                       ['2025-04-24T14:28:00+05:30',
#                        24251.8,
#                        24256.0,
#                        24251.0,
#                        24251.2,
#                        6600,
#                        5088300],
#                       ['2025-04-24T14:27:00+05:30',
#                        24251.9,
#                        24257.5,
#                        24251.7,
#                        24252.0,
#                        6075,
#                        5090325],
#                       ['2025-04-24T14:26:00+05:30',
#                        24250.1,
#                        24255.0,
#                        24250.1,
#                        24251.1,
#                        3900,
#                        5090325],
#                       ['2025-04-24T14:25:00+05:30',
#                        24253.2,
#                        24255.0,
#                        24250.0,
#                        24250.3,
#                        3675,
#                        5090325],
#                       ['2025-04-24T14:24:00+05:30',
#                        24257.0,
#                        24258.8,
#                        24253.0,
#                        24253.2,
#                        2925,
#                        5093850],
#                       ['2025-04-24T14:23:00+05:30',
#                        24255.8,
#                        24260.0,
#                        24254.1,
#                        24258.0,
#                        4050,
#                        5093850],
#                       ['2025-04-24T14:22:00+05:30',
#                        24256.0,
#                        24260.0,
#                        24253.0,
#                        24259.8,
#                        3975,
#                        5093850],
#                       ['2025-04-24T14:21:00+05:30',
#                        24251.1,
#                        24256.0,
#                        24250.3,
#                        24256.0,
#                        7500,
#                        5091900],
#                       ['2025-04-24T14:20:00+05:30',
#                        24250.4,
#                        24252.2,
#                        24250.2,
#                        24250.8,
#                        20775,
#                        5091900],
#                       ['2025-04-24T14:19:00+05:30',
#                        24250.1,
#                        24250.8,
#                        24249.8,
#                        24250.5,
#                        6375,
#                        5091900],
#                       ['2025-04-24T14:18:00+05:30',
#                        24249.6,
#                        24251.0,
#                        24248.9,
#                        24250.0,
#                        6150,
#                        5102175],
#                       ['2025-04-24T14:17:00+05:30',
#                        24248.1,
#                        24250.0,
#                        24248.1,
#                        24250.0,
#                        6900,
#                        5102175],
#                       ['2025-04-24T14:16:00+05:30',
#                        24250.9,
#                        24252.8,
#                        24248.1,
#                        24248.1,
#                        9000,
#                        5102175],
#                       ['2025-04-24T14:15:00+05:30',
#                        24250.6,
#                        24250.9,
#                        24249.5,
#                        24250.3,
#                        14775,
#                        5104650],
#                       ['2025-04-24T14:14:00+05:30',
#                        24252.7,
#                        24252.7,
#                        24250.4,
#                        24250.4,
#                        7875,
#                        5104650],
#                       ['2025-04-24T14:13:00+05:30',
#                        24250.2,
#                        24252.5,
#                        24250.2,
#                        24250.6,
#                        15750,
#                        5104650],
#                       ['2025-04-24T14:12:00+05:30',
#                        24251.3,
#                        24251.3,
#                        24250.0,
#                        24250.0,
#                        3975,
#                        5102250],
#                       ['2025-04-24T14:11:00+05:30',
#                        24251.4,
#                        24252.8,
#                        24249.8,
#                        24251.3,
#                        9225,
#                        5102250],
#                       ['2025-04-24T14:10:00+05:30',
#                        24252.3,
#                        24252.7,
#                        24250.0,
#                        24251.3,
#                        7425,
#                        5102250],
#                       ['2025-04-24T14:09:00+05:30',
#                        24252.3,
#                        24252.8,
#                        24251.5,
#                        24252.5,
#                        2925,
#                        5107575],
#                       ['2025-04-24T14:08:00+05:30',
#                        24251.4,
#                        24253.0,
#                        24251.4,
#                        24252.0,
#                        2400,
#                        5107575],
#                       ['2025-04-24T14:07:00+05:30',
#                        24250.1,
#                        24253.7,
#                        24249.9,
#                        24250.9,
#                        8550,
#                        5107575],
#                       ['2025-04-24T14:06:00+05:30',
#                        24251.6,
#                        24255.0,
#                        24249.7,
#                        24250.3,
#                        4950,
#                        5117400],
#                       ['2025-04-24T14:05:00+05:30',
#                        24254.0,
#                        24256.7,
#                        24250.4,
#                        24251.2,
#                        1800,
#                        5117400],
#                       ['2025-04-24T14:04:00+05:30',
#                        24251.2,
#                        24256.1,
#                        24251.2,
#                        24256.1,
#                        2850,
#                        5117400],
#                       ['2025-04-24T14:03:00+05:30',
#                        24252.0,
#                        24256.5,
#                        24250.1,
#                        24250.6,
#                        4800,
#                        5122650],
#                       ['2025-04-24T14:02:00+05:30',
#                        24251.3,
#                        24251.3,
#                        24248.7,
#                        24250.0,
#                        3525,
#                        5122650],
#                       ['2025-04-24T14:01:00+05:30',
#                        24259.2,
#                        24259.3,
#                        24249.6,
#                        24249.8,
#                        4275,
#                        5122650],
#                       ['2025-04-24T14:00:00+05:30',
#                        24250.0,
#                        24261.0,
#                        24248.7,
#                        24257.0,
#                        8550,
#                        5133600],
#                       ['2025-04-24T13:59:00+05:30',
#                        24251.0,
#                        24254.1,
#                        24250.0,
#                        24251.0,
#                        5850,
#                        5133600],
#                       ['2025-04-24T13:58:00+05:30',
#                        24250.0,
#                        24255.0,
#                        24248.4,
#                        24251.0,
#                        6750,
#                        5133600],
#                       ['2025-04-24T13:57:00+05:30',
#                        24248.8,
#                        24250.9,
#                        24248.0,
#                        24250.0,
#                        3150,
#                        5136525],
#                       ['2025-04-24T13:56:00+05:30',
#                        24248.0,
#                        24250.0,
#                        24247.6,
#                        24248.9,
#                        2175,
#                        5136525],
#                       ['2025-04-24T13:55:00+05:30',
#                        24248.5,
#                        24250.0,
#                        24246.8,
#                        24248.0,
#                        1425,
#                        5136525],
#                       ['2025-04-24T13:54:00+05:30',
#                        24246.2,
#                        24248.0,
#                        24246.0,
#                        24246.6,
#                        3600,
#                        5131350],
#                       ['2025-04-24T13:53:00+05:30',
#                        24249.9,
#                        24250.0,
#                        24245.8,
#                        24246.1,
#                        4125,
#                        5131350],
#                       ['2025-04-24T13:52:00+05:30',
#                        24246.9,
#                        24250.0,
#                        24246.6,
#                        24246.6,
#                        2475,
#                        5131350],
#                       ['2025-04-24T13:51:00+05:30',
#                        24252.0,
#                        24252.0,
#                        24245.7,
#                        24246.2,
#                        7050,
#                        5133675],
#                       ['2025-04-24T13:50:00+05:30',
#                        24245.5,
#                        24252.0,
#                        24245.5,
#                        24252.0,
#                        5100,
#                        5133675],
#                       ['2025-04-24T13:49:00+05:30',
#                        24250.0,
#                        24250.0,
#                        24245.7,
#                        24250.0,
#                        4125,
#                        5133675],
#                       ['2025-04-24T13:48:00+05:30',
#                        24250.0,
#                        24250.6,
#                        24248.5,
#                        24250.0,
#                        1800,
#                        5130600],
#                       ['2025-04-24T13:47:00+05:30',
#                        24249.9,
#                        24251.0,
#                        24249.9,
#                        24250.0,
#                        2325,
#                        5130600],
#                       ['2025-04-24T13:46:00+05:30',
#                        24247.0,
#                        24250.0,
#                        24247.0,
#                        24250.0,
#                        1725,
#                        5130600],
#                       ['2025-04-24T13:45:00+05:30',
#                        24247.0,
#                        24249.5,
#                        24246.8,
#                        24249.5,
#                        2325,
#                        5128425],
#                       ['2025-04-24T13:44:00+05:30',
#                        24244.4,
#                        24247.8,
#                        24244.4,
#                        24247.0,
#                        1650,
#                        5128425],
#                       ['2025-04-24T13:43:00+05:30',
#                        24248.9,
#                        24248.9,
#                        24243.2,
#                        24247.8,
#                        3975,
#                        5128425],
#                       ['2025-04-24T13:42:00+05:30',
#                        24244.5,
#                        24249.6,
#                        24243.9,
#                        24248.6,
#                        5475,
#                        5126400],
#                       ['2025-04-24T13:41:00+05:30',
#                        24244.7,
#                        24246.1,
#                        24244.3,
#                        24244.3,
#                        4650,
#                        5126400],
#                       ['2025-04-24T13:40:00+05:30',
#                        24242.0,
#                        24246.1,
#                        24241.5,
#                        24243.7,
#                        8025,
#                        5126400],
#                       ['2025-04-24T13:39:00+05:30',
#                        24242.2,
#                        24245.0,
#                        24241.5,
#                        24241.5,
#                        3300,
#                        5130675],
#                       ['2025-04-24T13:38:00+05:30',
#                        24241.0,
#                        24246.7,
#                        24239.0,
#                        24243.0,
#                        16425,
#                        5130675],
#                       ['2025-04-24T13:37:00+05:30',
#                        24247.1,
#                        24252.1,
#                        24241.0,
#                        24241.2,
#                        8775,
#                        5130675],
#                       ['2025-04-24T13:36:00+05:30',
#                        24249.0,
#                        24253.0,
#                        24247.1,
#                        24253.0,
#                        3225,
#                        5176275],
#                       ['2025-04-24T13:35:00+05:30',
#                        24250.5,
#                        24252.9,
#                        24249.0,
#                        24249.0,
#                        2025,
#                        5176275],
#                       ['2025-04-24T13:34:00+05:30',
#                        24254.7,
#                        24254.7,
#                        24250.0,
#                        24250.0,
#                        4350,
#                        5176275],
#                       ['2025-04-24T13:33:00+05:30',
#                        24254.9,
#                        24255.9,
#                        24254.7,
#                        24255.0,
#                        2325,
#                        5176500],
#                       ['2025-04-24T13:32:00+05:30',
#                        24251.7,
#                        24255.0,
#                        24251.7,
#                        24254.7,
#                        6750,
#                        5176500],
#                       ['2025-04-24T13:31:00+05:30',
#                        24250.0,
#                        24252.0,
#                        24250.0,
#                        24252.0,
#                        600,
#                        5176500],
#                       ['2025-04-24T13:30:00+05:30',
#                        24248.1,
#                        24250.0,
#                        24248.1,
#                        24250.0,
#                        1800,
#                        5174325],
#                       ['2025-04-24T13:29:00+05:30',
#                        24248.7,
#                        24250.0,
#                        24247.1,
#                        24247.9,
#                        3075,
#                        5174325],
#                       ['2025-04-24T13:28:00+05:30',
#                        24249.8,
#                        24249.9,
#                        24248.5,
#                        24248.7,
#                        975,
#                        5174325],
#                       ['2025-04-24T13:27:00+05:30',
#                        24248.5,
#                        24249.9,
#                        24248.3,
#                        24249.8,
#                        1350,
#                        5171625],
#                       ['2025-04-24T13:26:00+05:30',
#                        24249.5,
#                        24249.9,
#                        24248.6,
#                        24248.7,
#                        5475,
#                        5171625],
#                       ['2025-04-24T13:25:00+05:30',
#                        24249.9,
#                        24249.9,
#                        24248.9,
#                        24249.6,
#                        3600,
#                        5171625],
#                       ['2025-04-24T13:24:00+05:30',
#                        24247.8,
#                        24250.0,
#                        24247.6,
#                        24249.9,
#                        2700,
#                        5167725],
#                       ['2025-04-24T13:23:00+05:30',
#                        24246.0,
#                        24250.0,
#                        24245.9,
#                        24248.0,
#                        3150,
#                        5167725],
#                       ['2025-04-24T13:22:00+05:30',
#                        24248.0,
#                        24248.1,
#                        24245.9,
#                        24247.0,
#                        4875,
#                        5167725],
#                       ['2025-04-24T13:21:00+05:30',
#                        24248.4,
#                        24252.4,
#                        24246.8,
#                        24248.1,
#                        7050,
#                        5167350],
#                       ['2025-04-24T13:20:00+05:30',
#                        24249.0,
#                        24250.0,
#                        24248.4,
#                        24248.5,
#                        1350,
#                        5167350],
#                       ['2025-04-24T13:19:00+05:30',
#                        24250.0,
#                        24255.0,
#                        24248.2,
#                        24248.4,
#                        6750,
#                        5167350],
#                       ['2025-04-24T13:18:00+05:30',
#                        24251.1,
#                        24254.7,
#                        24248.4,
#                        24249.2,
#                        6225,
#                        5172075],
#                       ['2025-04-24T13:17:00+05:30',
#                        24250.0,
#                        24255.0,
#                        24249.2,
#                        24250.5,
#                        1350,
#                        5172075],
#                       ['2025-04-24T13:16:00+05:30',
#                        24251.8,
#                        24253.0,
#                        24248.0,
#                        24253.0,
#                        3375,
#                        5172075],
#                       ['2025-04-24T13:15:00+05:30',
#                        24250.6,
#                        24254.7,
#                        24250.0,
#                        24250.0,
#                        7950,
#                        5174925],
#                       ['2025-04-24T13:14:00+05:30',
#                        24254.2,
#                        24254.2,
#                        24250.1,
#                        24251.0,
#                        600,
#                        5174925],
#                       ['2025-04-24T13:13:00+05:30',
#                        24251.2,
#                        24254.9,
#                        24250.0,
#                        24253.1,
#                        2175,
#                        5174925],
#                       ['2025-04-24T13:12:00+05:30',
#                        24251.8,
#                        24254.6,
#                        24250.2,
#                        24251.4,
#                        2175,
#                        5174550],
#                       ['2025-04-24T13:11:00+05:30',
#                        24254.5,
#                        24255.0,
#                        24251.7,
#                        24255.0,
#                        4725,
#                        5174550],
#                       ['2025-04-24T13:10:00+05:30',
#                        24253.7,
#                        24256.0,
#                        24252.1,
#                        24253.5,
#                        2550,
#                        5174550],
#                       ['2025-04-24T13:09:00+05:30',
#                        24253.5,
#                        24255.9,
#                        24252.6,
#                        24253.6,
#                        3750,
#                        5178075],
#                       ['2025-04-24T13:08:00+05:30',
#                        24252.3,
#                        24255.2,
#                        24251.7,
#                        24252.3,
#                        2400,
#                        5178075],
#                       ['2025-04-24T13:07:00+05:30',
#                        24254.5,
#                        24255.6,
#                        24252.0,
#                        24255.6,
#                        4050,
#                        5178075],
#                       ['2025-04-24T13:06:00+05:30',
#                        24254.4,
#                        24255.9,
#                        24251.7,
#                        24251.9,
#                        5400,
#                        5200725],
#                       ['2025-04-24T13:05:00+05:30',
#                        24252.5,
#                        24255.5,
#                        24252.2,
#                        24252.7,
#                        2325,
#                        5200725],
#                       ['2025-04-24T13:04:00+05:30',
#                        24252.6,
#                        24255.6,
#                        24252.0,
#                        24252.3,
#                        2400,
#                        5200725],
#                       ['2025-04-24T13:03:00+05:30',
#                        24254.9,
#                        24256.0,
#                        24252.0,
#                        24252.1,
#                        3675,
#                        5199750],
#                       ['2025-04-24T13:02:00+05:30',
#                        24251.1,
#                        24255.0,
#                        24251.1,
#                        24253.1,
#                        4275,
#                        5199750],
#                       ['2025-04-24T13:01:00+05:30',
#                        24252.9,
#                        24252.9,
#                        24250.2,
#                        24251.0,
#                        1800,
#                        5199750],
#                       ['2025-04-24T13:00:00+05:30',
#                        24254.3,
#                        24255.0,
#                        24252.0,
#                        24253.0,
#                        4575,
#                        5209350],
#                       ['2025-04-24T12:59:00+05:30',
#                        24252.6,
#                        24255.0,
#                        24252.0,
#                        24254.2,
#                        1350,
#                        5209350],
#                       ['2025-04-24T12:58:00+05:30',
#                        24255.4,
#                        24255.4,
#                        24252.1,
#                        24253.1,
#                        1650,
#                        5209350],
#                       ['2025-04-24T12:57:00+05:30',
#                        24256.3,
#                        24257.0,
#                        24254.9,
#                        24255.9,
#                        4725,
#                        5210850],
#                       ['2025-04-24T12:56:00+05:30',
#                        24256.1,
#                        24257.1,
#                        24256.0,
#                        24256.9,
#                        2025,
#                        5210850],
#                       ['2025-04-24T12:55:00+05:30',
#                        24253.5,
#                        24256.2,
#                        24253.5,
#                        24256.2,
#                        3225,
#                        5210850],
#                       ['2025-04-24T12:54:00+05:30',
#                        24257.7,
#                        24258.0,
#                        24253.3,
#                        24253.3,
#                        4200,
#                        5215725],
#                       ['2025-04-24T12:53:00+05:30',
#                        24257.1,
#                        24257.8,
#                        24255.1,
#                        24257.6,
#                        3975,
#                        5215725],
#                       ['2025-04-24T12:52:00+05:30',
#                        24258.1,
#                        24259.7,
#                        24254.2,
#                        24256.7,
#                        3450,
#                        5215725],
#                       ['2025-04-24T12:51:00+05:30',
#                        24257.1,
#                        24259.5,
#                        24253.4,
#                        24253.4,
#                        7200,
#                        5221500],
#                       ['2025-04-24T12:50:00+05:30',
#                        24258.5,
#                        24260.0,
#                        24251.4,
#                        24257.9,
#                        8175,
#                        5221500],
#                       ['2025-04-24T12:49:00+05:30',
#                        24259.3,
#                        24259.3,
#                        24256.1,
#                        24258.2,
#                        2775,
#                        5221500],
#                       ['2025-04-24T12:48:00+05:30',
#                        24256.2,
#                        24260.0,
#                        24256.2,
#                        24257.8,
#                        2775,
#                        5217750],
#                       ['2025-04-24T12:47:00+05:30',
#                        24256.1,
#                        24259.1,
#                        24256.1,
#                        24258.8,
#                        4200,
#                        5217750],
#                       ['2025-04-24T12:46:00+05:30',
#                        24257.1,
#                        24258.9,
#                        24256.1,
#                        24256.1,
#                        1800,
#                        5217750],
#                       ['2025-04-24T12:45:00+05:30',
#                        24256.7,
#                        24258.9,
#                        24256.6,
#                        24257.1,
#                        2625,
#                        5216700],
#                       ['2025-04-24T12:44:00+05:30',
#                        24257.0,
#                        24258.5,
#                        24256.6,
#                        24256.7,
#                        1800,
#                        5216700],
#                       ['2025-04-24T12:43:00+05:30',
#                        24254.6,
#                        24258.2,
#                        24253.9,
#                        24257.6,
#                        3975,
#                        5216700],
#                       ['2025-04-24T12:42:00+05:30',
#                        24254.0,
#                        24256.4,
#                        24252.3,
#                        24254.6,
#                        3900,
#                        5215350],
#                       ['2025-04-24T12:41:00+05:30',
#                        24251.0,
#                        24255.4,
#                        24248.9,
#                        24252.3,
#                        6525,
#                        5215350],
#                       ['2025-04-24T12:40:00+05:30',
#                        24248.9,
#                        24251.0,
#                        24248.6,
#                        24250.1,
#                        2400,
#                        5215350],
#                       ['2025-04-24T12:39:00+05:30',
#                        24248.3,
#                        24251.0,
#                        24247.4,
#                        24249.2,
#                        4650,
#                        5216325],
#                       ['2025-04-24T12:38:00+05:30',
#                        24245.7,
#                        24247.4,
#                        24245.3,
#                        24247.4,
#                        6675,
#                        5216325],
#                       ['2025-04-24T12:37:00+05:30',
#                        24243.5,
#                        24250.0,
#                        24243.5,
#                        24245.8,
#                        5775,
#                        5216325],
#                       ['2025-04-24T12:36:00+05:30',
#                        24242.3,
#                        24249.3,
#                        24242.3,
#                        24243.5,
#                        11175,
#                        5220675],
#                       ['2025-04-24T12:35:00+05:30',
#                        24250.0,
#                        24251.0,
#                        24240.5,
#                        24242.6,
#                        11100,
#                        5220675],
#                       ['2025-04-24T12:34:00+05:30',
#                        24250.0,
#                        24251.0,
#                        24249.0,
#                        24250.0,
#                        5250,
#                        5220675],
#                       ['2025-04-24T12:33:00+05:30',
#                        24251.1,
#                        24252.6,
#                        24250.0,
#                        24250.1,
#                        3975,
#                        5222475],
#                       ['2025-04-24T12:32:00+05:30',
#                        24257.0,
#                        24257.0,
#                        24250.1,
#                        24250.2,
#                        4650,
#                        5222475],
#                       ['2025-04-24T12:31:00+05:30',
#                        24249.9,
#                        24256.1,
#                        24249.5,
#                        24251.0,
#                        3525,
#                        5222475],
#                       ['2025-04-24T12:30:00+05:30',
#                        24250.0,
#                        24251.0,
#                        24247.9,
#                        24250.0,
#                        16875,
#                        5232450],
#                       ['2025-04-24T12:29:00+05:30',
#                        24251.5,
#                        24251.5,
#                        24250.0,
#                        24250.0,
#                        5325,
#                        5232450],
#                       ['2025-04-24T12:28:00+05:30',
#                        24252.1,
#                        24253.0,
#                        24251.1,
#                        24251.7,
#                        4500,
#                        5232450],
#                       ['2025-04-24T12:27:00+05:30',
#                        24253.0,
#                        24256.1,
#                        24252.1,
#                        24252.1,
#                        2475,
#                        5231325],
#                       ['2025-04-24T12:26:00+05:30',
#                        24253.1,
#                        24255.2,
#                        24253.0,
#                        24253.0,
#                        1950,
#                        5231325],
#                       ['2025-04-24T12:25:00+05:30',
#                        24256.1,
#                        24258.1,
#                        24253.1,
#                        24253.1,
#                        2700,
#                        5231325],
#                       ['2025-04-24T12:24:00+05:30',
#                        24256.1,
#                        24256.3,
#                        24252.6,
#                        24255.4,
#                        5700,
#                        5242275],
#                       ['2025-04-24T12:23:00+05:30',
#                        24260.3,
#                        24260.3,
#                        24255.1,
#                        24256.1,
#                        5175,
#                        5242275],
#                       ['2025-04-24T12:22:00+05:30',
#                        24261.1,
#                        24261.8,
#                        24260.1,
#                        24260.5,
#                        2175,
#                        5242275],
#                       ['2025-04-24T12:21:00+05:30',
#                        24260.3,
#                        24261.4,
#                        24260.1,
#                        24261.2,
#                        2550,
#                        5249100],
#                       ['2025-04-24T12:20:00+05:30',
#                        24260.0,
#                        24260.9,
#                        24260.0,
#                        24260.8,
#                        3375,
#                        5249100],
#                       ['2025-04-24T12:19:00+05:30',
#                        24259.2,
#                        24260.0,
#                        24256.3,
#                        24260.0,
#                        1650,
#                        5249100],
#                       ['2025-04-24T12:18:00+05:30',
#                        24255.9,
#                        24259.5,
#                        24255.2,
#                        24259.5,
#                        4725,
#                        5247450],
#                       ['2025-04-24T12:17:00+05:30',
#                        24253.3,
#                        24255.9,
#                        24253.1,
#                        24255.2,
#                        6300,
#                        5247450],
#                       ['2025-04-24T12:16:00+05:30',
#                        24251.5,
#                        24255.5,
#                        24251.4,
#                        24253.3,
#                        4050,
#                        5247450],
#                       ['2025-04-24T12:15:00+05:30',
#                        24251.0,
#                        24251.5,
#                        24249.7,
#                        24251.5,
#                        8325,
#                        5254500],
#                       ['2025-04-24T12:14:00+05:30',
#                        24250.3,
#                        24251.0,
#                        24249.1,
#                        24250.6,
#                        7500,
#                        5254500],
#                       ['2025-04-24T12:13:00+05:30',
#                        24253.1,
#                        24254.5,
#                        24250.0,
#                        24250.2,
#                        2700,
#                        5254500],
#                       ['2025-04-24T12:12:00+05:30',
#                        24254.0,
#                        24255.7,
#                        24250.0,
#                        24253.0,
#                        2850,
#                        5251500],
# ...
#                       ['2025-04-11T10:19:00+05:30',
#                        22891.0,
#                        22898.55,
#                        22887.95,
#                        22890.0,
#                        12000,
#                        13158150],
#                       ['2025-04-11T10:18:00+05:30',
#                        22908.45,
#                        22912.3,
#                        22892.5,
#                        22892.5,
#                        22200,
#                        13158150],
#                       ['2025-04-11T10:17:00+05:30',
#                        22908.6,
#                        22910.85,
#                        22901.1,
#                        22908.2,
#                        9000,
#                        13167675],
#                       ['2025-04-11T10:16:00+05:30',
#                        22912.15,
#                        22918.25,
#                        22903.0,
#                        22909.55,
#                        9375,
#                        13167675],
#                       ['2025-04-11T10:15:00+05:30',
#                        22905.0,
#                        22918.85,
#                        22905.0,
#                        22916.0,
#                        13200,
#                        13167675],
#                       ['2025-04-11T10:14:00+05:30',
#                        22910.0,
#                        22912.5,
#                        22898.95,
#                        22905.65,
#                        40425,
#                        13180950],
#                       ['2025-04-11T10:13:00+05:30',
#                        22909.45,
#                        22915.65,
#                        22896.0,
#                        22913.15,
#                        19425,
#                        13180950],
#                       ['2025-04-11T10:12:00+05:30',
#                        22898.3,
#                        22916.15,
#                        22896.0,
#                        22908.85,
#                        19575,
#                        13180950],
#                       ['2025-04-11T10:11:00+05:30',
#                        22884.95,
#                        22905.7,
#                        22883.05,
#                        22899.7,
#                        21750,
#                        13172550],
#                       ['2025-04-11T10:10:00+05:30',
#                        22892.0,
#                        22897.45,
#                        22883.1,
#                        22883.25,
#                        42450,
#                        13172550],
#                       ['2025-04-11T10:09:00+05:30',
#                        22910.0,
#                        22910.25,
#                        22890.0,
#                        22890.95,
#                        30825,
#                        13172550],
#                       ['2025-04-11T10:08:00+05:30',
#                        22899.0,
#                        22909.8,
#                        22897.9,
#                        22904.6,
#                        33150,
#                        13162725],
#                       ['2025-04-11T10:07:00+05:30',
#                        22907.3,
#                        22912.1,
#                        22898.9,
#                        22899.0,
#                        87750,
#                        13162725],
#                       ['2025-04-11T10:06:00+05:30',
#                        22930.0,
#                        22930.0,
#                        22905.55,
#                        22910.0,
#                        26175,
#                        13162725],
#                       ['2025-04-11T10:05:00+05:30',
#                        22927.3,
#                        22940.0,
#                        22921.05,
#                        22930.0,
#                        32025,
#                        13156800],
#                       ['2025-04-11T10:04:00+05:30',
#                        22931.6,
#                        22932.75,
#                        22923.0,
#                        22927.3,
#                        14850,
#                        13156800],
#                       ['2025-04-11T10:03:00+05:30',
#                        22947.0,
#                        22947.25,
#                        22930.0,
#                        22932.75,
#                        10050,
#                        13156800],
#                       ['2025-04-11T10:02:00+05:30',
#                        22946.0,
#                        22953.7,
#                        22944.1,
#                        22947.0,
#                        31125,
#                        13146225],
#                       ['2025-04-11T10:01:00+05:30',
#                        22925.7,
#                        22950.0,
#                        22925.7,
#                        22948.9,
#                        29025,
#                        13146225],
#                       ['2025-04-11T10:00:00+05:30',
#                        22920.0,
#                        22935.0,
#                        22916.95,
#                        22925.4,
#                        20775,
#                        13146225],
#                       ['2025-04-11T09:59:00+05:30',
#                        22922.8,
#                        22938.45,
#                        22915.8,
#                        22916.8,
#                        42075,
#                        13158675],
#                       ['2025-04-11T09:58:00+05:30',
#                        22942.0,
#                        22947.0,
#                        22906.3,
#                        22921.05,
#                        67875,
#                        13158675],
#                       ['2025-04-11T09:57:00+05:30',
#                        22954.2,
#                        22959.4,
#                        22942.05,
#                        22945.15,
#                        24900,
#                        13158675],
#                       ['2025-04-11T09:56:00+05:30',
#                        22947.65,
#                        22963.4,
#                        22947.65,
#                        22957.6,
#                        31725,
#                        13154700],
#                       ['2025-04-11T09:55:00+05:30',
#                        22949.45,
#                        22955.0,
#                        22940.5,
#                        22947.85,
#                        23400,
#                        13154700],
#                       ['2025-04-11T09:54:00+05:30',
#                        22946.0,
#                        22954.0,
#                        22935.25,
#                        22952.9,
#                        25500,
#                        13154700],
#                       ['2025-04-11T09:53:00+05:30',
#                        22941.05,
#                        22949.95,
#                        22933.3,
#                        22945.0,
#                        28875,
#                        13172700],
#                       ['2025-04-11T09:52:00+05:30',
#                        22942.5,
#                        22950.25,
#                        22941.0,
#                        22941.15,
#                        19950,
#                        13172700],
#                       ['2025-04-11T09:51:00+05:30',
#                        22945.05,
#                        22955.0,
#                        22940.85,
#                        22942.45,
#                        20850,
#                        13172700],
#                       ['2025-04-11T09:50:00+05:30',
#                        22964.45,
#                        22969.15,
#                        22943.0,
#                        22943.0,
#                        45525,
#                        13164075],
#                       ['2025-04-11T09:49:00+05:30',
#                        22944.95,
#                        22970.0,
#                        22940.0,
#                        22965.0,
#                        93750,
#                        13164075],
#                       ['2025-04-11T09:48:00+05:30',
#                        22933.0,
#                        22947.95,
#                        22930.0,
#                        22945.0,
#                        30900,
#                        13164075],
#                       ['2025-04-11T09:47:00+05:30',
#                        22931.95,
#                        22934.0,
#                        22924.4,
#                        22930.9,
#                        20475,
#                        13163025],
#                       ['2025-04-11T09:46:00+05:30',
#                        22934.0,
#                        22937.95,
#                        22924.9,
#                        22931.5,
#                        29250,
#                        13163025],
#                       ['2025-04-11T09:45:00+05:30',
#                        22935.45,
#                        22947.7,
#                        22930.25,
#                        22930.25,
#                        34050,
#                        13163025],
#                       ['2025-04-11T09:44:00+05:30',
#                        22935.45,
#                        22949.9,
#                        22932.8,
#                        22935.5,
#                        53850,
#                        13150875],
#                       ['2025-04-11T09:43:00+05:30',
#                        22935.95,
#                        22944.8,
#                        22928.0,
#                        22937.85,
#                        28800,
#                        13150875],
#                       ['2025-04-11T09:42:00+05:30',
#                        22927.2,
#                        22939.95,
#                        22927.2,
#                        22934.95,
#                        25875,
#                        13150875],
#                       ['2025-04-11T09:41:00+05:30',
#                        22931.0,
#                        22945.65,
#                        22925.0,
#                        22926.0,
#                        72750,
#                        13142625],
#                       ['2025-04-11T09:40:00+05:30',
#                        22930.0,
#                        22938.65,
#                        22921.25,
#                        22932.4,
#                        51075,
#                        13142625],
#                       ['2025-04-11T09:39:00+05:30',
#                        22930.0,
#                        22939.0,
#                        22926.35,
#                        22930.3,
#                        38925,
#                        13142625],
#                       ['2025-04-11T09:38:00+05:30',
#                        22928.0,
#                        22935.35,
#                        22925.0,
#                        22930.0,
#                        40050,
#                        13125975],
#                       ['2025-04-11T09:37:00+05:30',
#                        22924.05,
#                        22942.25,
#                        22915.8,
#                        22930.0,
#                        51300,
#                        13125975],
#                       ['2025-04-11T09:36:00+05:30',
#                        22880.0,
#                        22932.0,
#                        22880.0,
#                        22922.0,
#                        183075,
#                        13125975],
#                       ['2025-04-11T09:35:00+05:30',
#                        22883.55,
#                        22885.0,
#                        22875.35,
#                        22880.0,
#                        30075,
#                        13146075],
#                       ['2025-04-11T09:34:00+05:30',
#                        22862.0,
#                        22885.0,
#                        22859.55,
#                        22885.0,
#                        33825,
#                        13146075],
#                       ['2025-04-11T09:33:00+05:30',
#                        22857.0,
#                        22864.0,
#                        22852.9,
#                        22860.55,
#                        15375,
#                        13146075],
#                       ['2025-04-11T09:32:00+05:30',
#                        22849.35,
#                        22860.0,
#                        22845.6,
#                        22858.85,
#                        22500,
#                        13162575],
#                       ['2025-04-11T09:31:00+05:30',
#                        22860.75,
#                        22864.0,
#                        22850.0,
#                        22850.0,
#                        31650,
#                        13162575],
#                       ['2025-04-11T09:30:00+05:30',
#                        22845.25,
#                        22871.0,
#                        22845.25,
#                        22856.2,
#                        47325,
#                        13162575],
#                       ['2025-04-11T09:29:00+05:30',
#                        22848.15,
#                        22862.65,
#                        22845.0,
#                        22848.8,
#                        39750,
#                        13175775],
#                       ['2025-04-11T09:28:00+05:30',
#                        22859.75,
#                        22871.85,
#                        22845.9,
#                        22845.9,
#                        57825,
#                        13175775],
#                       ['2025-04-11T09:27:00+05:30',
#                        22856.55,
#                        22876.85,
#                        22847.65,
#                        22855.0,
#                        58950,
#                        13175775],
#                       ['2025-04-11T09:26:00+05:30',
#                        22878.4,
#                        22880.0,
#                        22852.3,
#                        22856.05,
#                        43875,
#                        13188225],
#                       ['2025-04-11T09:25:00+05:30',
#                        22895.2,
#                        22899.9,
#                        22875.25,
#                        22875.25,
#                        62850,
#                        13188225],
#                       ['2025-04-11T09:24:00+05:30',
#                        22866.05,
#                        22895.4,
#                        22864.05,
#                        22895.2,
#                        89700,
#                        13188225],
#                       ['2025-04-11T09:23:00+05:30',
#                        22851.0,
#                        22866.95,
#                        22847.75,
#                        22866.05,
#                        67650,
#                        13231050],
#                       ['2025-04-11T09:22:00+05:30',
#                        22849.45,
#                        22859.0,
#                        22847.05,
#                        22851.0,
#                        94425,
#                        13231050],
#                       ['2025-04-11T09:21:00+05:30',
#                        22840.0,
#                        22851.0,
#                        22833.6,
#                        22848.8,
#                        61200,
#                        13231050],
#                       ['2025-04-11T09:20:00+05:30',
#                        22849.9,
#                        22855.0,
#                        22835.25,
#                        22842.7,
#                        118350,
#                        13265550],
#                       ['2025-04-11T09:19:00+05:30',
#                        22859.85,
#                        22860.95,
#                        22833.05,
#                        22849.9,
#                        73125,
#                        13265550],
#                       ['2025-04-11T09:18:00+05:30',
#                        22845.2,
#                        22863.0,
#                        22845.0,
#                        22858.0,
#                        106425,
#                        13265550],
#                       ['2025-04-11T09:17:00+05:30',
#                        22830.05,
#                        22849.0,
#                        22825.05,
#                        22845.0,
#                        130200,
#                        13164525],
#                       ['2025-04-11T09:16:00+05:30',
#                        22816.0,
#                        22850.0,
#                        22811.0,
#                        22830.35,
#                        252075,
#                        13164525],
#                       ['2025-04-11T09:15:00+05:30',
#                        22746.0,
#                        22900.0,
#                        22746.0,
#                        22816.0,
#                        539250,
#                        13164525]]},
#  'status': 'success'}

# %%
data=response.data.candles
data=pd.DataFrame(data,columns=['Timestamp','Open','High','Low','Close','Volume','Open Interest'])
data['Timestamp']=pd.to_datetime(data['Timestamp'])
data=data.set_index('Timestamp')
data=data.sort_index()
data
# Out:
#                                Open      High       Low     Close  Volume  \
# Timestamp
# 2025-04-11 09:15:00+05:30  22746.00  22900.00  22746.00  22816.00  539250
# 2025-04-11 09:16:00+05:30  22816.00  22850.00  22811.00  22830.35  252075
# 2025-04-11 09:17:00+05:30  22830.05  22849.00  22825.05  22845.00  130200
# 2025-04-11 09:18:00+05:30  22845.20  22863.00  22845.00  22858.00  106425
# 2025-04-11 09:19:00+05:30  22859.85  22860.95  22833.05  22849.90   73125
# ...                             ...       ...       ...       ...     ...
# 2025-04-24 15:25:00+05:30  24247.20  24249.00  24246.80  24247.00   13275
# 2025-04-24 15:26:00+05:30  24248.80  24248.80  24246.00  24248.00    9375
# 2025-04-24 15:27:00+05:30  24248.00  24250.00  24248.00  24248.20   12525
# 2025-04-24 15:28:00+05:30  24249.90  24250.00  24247.00  24249.30    9600
# 2025-04-24 15:29:00+05:30  24249.70  24250.00  24246.00  24249.00   10875
#
#                            Open Interest
# Timestamp
# 2025-04-11 09:15:00+05:30       13164525
# 2025-04-11 09:16:00+05:30       13164525
# 2025-04-11 09:17:00+05:30       13164525
# 2025-04-11 09:18:00+05:30       13265550
# 2025-04-11 09:19:00+05:30       13265550
# ...                                  ...
# 2025-04-24 15:25:00+05:30        4880250
# 2025-04-24 15:26:00+05:30        4880250
# 2025-04-24 15:27:00+05:30        4880250
# 2025-04-24 15:28:00+05:30        4850775
# 2025-04-24 15:29:00+05:30        4850775
#
# [3000 rows x 6 columns]
